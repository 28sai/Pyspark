# %%
# !pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/317.0 MB ? eta -:--:--
#      ---------------------------------------- 0.1/317.0 MB 1.1 MB/s eta 0:04:51
#      ---------------------------------------- 0.2/317.0 MB 1.7 MB/s eta 0:03:02
#      ---------------------------------------- 0.3/317.0 MB 2.3 MB/s eta 0:02:21
#      ---------------------------------------- 0.5/317.0 MB 2.9 MB/s eta 0:01:51
#      ---------------------------------------- 0.7/317.0 MB 2.8 MB/s eta 0:01:55
#      ---------------------------------------- 1.0/317.0 MB 3.6 MB/s eta 0:01:29
#      ---------------------------------------- 1.4/317.0 MB 4.2 MB/s eta 0:01:17
#      ---------------------------------------- 1.6/317.0 MB 4.2 MB/s eta 0:01:15
#      ---------------------------------------- 1.9/317.0 MB 4.7 MB/s eta 0:01:07
#      ---------------------------------------- 2.1/317.0 MB 4.5 MB/s eta 0:01:10
#      ---------------------------------------- 2.5/317.0 MB 4.9 MB/s eta 0:01:05
# ...

# %% [markdown]
# <h1>Session 1</h1>

# %%
import pyspark

# %%
import pandas as pd
df=pd.read_csv("test1.csv")

# %%
df
# Out:
#         Name  Age
# 0    Saiteja   22
# 1     Dinesh   24
# 2      Rohan   25
# 3  Suryateja   22

# %%
from pyspark.sql import SparkSession

#SparkSession is the entry point to programming with Spark with the Dataset and DataFrame API.
#It is essentially a unified interface for interacting with Spark SQL functionalities and underlying SparkContext.

# %%
spark=SparkSession.builder.appName("Practice").getOrCreate()

#is used to initialize a Spark session in PySpark, which is the Python API for Apache Spark.

# %% [raw]
# SparkSession.builder: This is a builder pattern used to create a SparkSession object.
#
#
# appName("Practice"): This sets the name of the Spark application to "Practice". This name will appear in the Spark web UI and can help you identify your application.
#
#
# getOrCreate(): This method either retrieves an existing SparkSession or creates a new one if none exists. This ensures that there is only one SparkSession per application.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://SaiTeja.bbrouter:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv("test1.csv")

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +---------+---+
# |      _c0|_c1|
# +---------+---+
# |     Name|Age|
# |  Saiteja| 22|
# |   Dinesh| 24|
# |    Rohan| 25|
# |Suryateja| 22|
# +---------+---+

# %%
spark.read.option('header',"true").csv("test1.csv")
# Out:
# DataFrame[Name: string, Age: string]

# %%
df_pyspark=spark.read.option('header',"true").csv("test1.csv")

# %%
df_pyspark.show()
# Out:
# +---------+---+
# |     Name|Age|
# +---------+---+
# |  Saiteja| 22|
# |   Dinesh| 24|
# |    Rohan| 25|
# |Suryateja| 22|
# +---------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Saiteja', Age='22'),
#  Row(Name='Dinesh', Age='24'),
#  Row(Name='Rohan', Age='25')]

# %%
df_pyspark.printSchema()   #like df.info()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
